# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.simplefilter('ignore')

df = pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df['Gender'] = df['Gender'].replace('Male',1).replace("Female" , 0)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    int64
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(5)
# memory usage: 7.9 KB

# %%
#Distribution of Annnual Income

plt.figure(figsize=(5, 3))
sns.set(style = 'whitegrid')
sns.distplot(df['Annual Income (k$)'])
plt.title('Distribution of Annual Income (k$)', fontsize = 20)
plt.xlabel('Range of Annual Income (k$)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Distribution of age

plt.figure(figsize=(5, 3))
sns.set(style = 'whitegrid')
sns.distplot(df['Age'])
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Distribution of spending score

plt.figure(figsize=(5, 3))
sns.set(style = 'whitegrid')
sns.distplot(df['Spending Score (1-100)'])
plt.title('Distribution of Spending Score (1-100)', fontsize = 20)
plt.xlabel('Range of Spending Score (1-100)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
genders = df.Gender.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(5,2))
sns.barplot(x=genders.index, y=genders.values)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Annual Income (k$)',y = 'Spending Score (1-100)'  , hue="Gender",data = df  ,s = 60 )
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)') 
plt.title('Spending Score (1-100) vs Annual Income (k$)')
plt.legend()
plt.show()

# %%
import scipy.cluster.hierarchy as sch

X = df[["Annual Income (k$)","Spending Score (1-100)"]]

data = sch.linkage(X, method = 'ward') # centroid distancing method

dendrogram = sch.dendrogram(data)

#plt.figure(figsize=(12,6))
plt.title("Dendogram")
plt.xlabel("Customers")
plt.ylabel("Euclidean Distance")

plt.show()

# %% [markdown]
# <h3> Here the total height is 400 and a horizontal line is drawn at 200..and 5 clusters are optimal. </h3>

# %%
from sklearn.cluster import AgglomerativeClustering 

hc = AgglomerativeClustering(n_clusters=5, metric='euclidean',linkage='ward')
df['label'] = hc.fit_predict(X)
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
#      label
# 0        4
# 1        3
# 2        4
# 3        3
# 4        4
# ..     ...
# 195      2
# 196      0
# 197      2
# 198      0
# 199      2
#
# [200 rows x 6 columns]

# %%
df["label"].value_counts()
# Out:
# 1    85
# 2    39
# 0    32
# 4    23
# 3    21
# Name: label, dtype: int64

# %%
#Scatterplot of the clusters

plt.figure(figsize=(10,6))
sns.scatterplot(x = 'Annual Income (k$)',y = 'Spending Score (1-100)',hue="label",  
                 palette=['green','orange','brown','dodgerblue','red'], legend='full',data = df  ,s = 60 )

plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)') 
plt.title('Spending Score (1-100) vs Annual Income (k$)')
plt.show()

# %%
df['label'] = df['label'].replace(0,'Neutral').replace(1 , 'High-Income-High-Spend').replace(2 , 'Low-Income-High-Spend').replace(3 , 'High-Income-Low-Spend').replace(4 , 'Low-Income-Low-Spend')

# %%
df['label'] = df['label'].replace(0,'Female').replace(1 , 'Male')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1       1   19                  15                      39
# 1           2       1   21                  15                      81
# 2           3       0   20                  16                       6
# 3           4       0   23                  16                      77
# 4           5       0   31                  17                      40
#
#                    label
# 0   Low-Income-Low-Spend
# 1  High-Income-Low-Spend
# 2   Low-Income-Low-Spend
# 3  High-Income-Low-Spend
# 4   Low-Income-Low-Spend

# %%
df_Low_Income_High_Spend = df[(df['label'] == 'Low-Income-High-Spend')] 
df_Low_Income_High_Spend
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 123         124       1   39                  69                      91
# 125         126       0   31                  70                      77
# 127         128       1   40                  71                      95
# 129         130       1   38                  71                      75
# 131         132       1   39                  71                      75
# 133         134       0   31                  72                      71
# 135         136       0   29                  73                      88
# 137         138       1   32                  73                      73
# 139         140       0   35                  74                      72
# 141         142       1   32                  75                      93
# 143         144       0   32                  76                      87
# 145         146       1   28                  77                      97
# 147         148       0   32                  77                      74
# 149         150       1   34                  78                      90
# 151         152       1   39                  78                      88
# 153         154       0   38                  78                      76
# 155         156       0   27                  78                      89
# 157         158       0   30                  78                      78
# 159         160       0   30                  78                      73
# 161         162       0   29                  79                      83
# 163         164       0   31                  81                      93
# 165         166       0   36                  85                      75
# 167         168       0   33                  86                      95
# 169         170       1   32                  87                      63
# 171         172       1   28                  87                      75
# 173         174       1   36                  87                      92
# 175         176       0   30                  88                      86
# 177         178       1   27                  88                      69
# 179         180       1   35                  93                      90
# 181         182       0   32                  97                      86
# 183         184       0   29                  98                      88
# 185         186       1   30                  99                      97
# 187         188       1   28                 101                      68
# 189         190       0   36                 103                      85
# 191         192       0   32                 103                      69
# 193         194       0   38                 113                      91
# 195         196       0   35                 120                      79
# 197         198       1   32                 126                      74
# 199         200       1   30                 137                      83
#
#                      label
# 123  Low-Income-High-Spend
# 125  Low-Income-High-Spend
# 127  Low-Income-High-Spend
# 129  Low-Income-High-Spend
# 131  Low-Income-High-Spend
# 133  Low-Income-High-Spend
# 135  Low-Income-High-Spend
# 137  Low-Income-High-Spend
# 139  Low-Income-High-Spend
# 141  Low-Income-High-Spend
# 143  Low-Income-High-Spend
# 145  Low-Income-High-Spend
# 147  Low-Income-High-Spend
# 149  Low-Income-High-Spend
# 151  Low-Income-High-Spend
# 153  Low-Income-High-Spend
# 155  Low-Income-High-Spend
# 157  Low-Income-High-Spend
# 159  Low-Income-High-Spend
# 161  Low-Income-High-Spend
# 163  Low-Income-High-Spend
# 165  Low-Income-High-Spend
# 167  Low-Income-High-Spend
# 169  Low-Income-High-Spend
# 171  Low-Income-High-Spend
# 173  Low-Income-High-Spend
# 175  Low-Income-High-Spend
# 177  Low-Income-High-Spend
# 179  Low-Income-High-Spend
# 181  Low-Income-High-Spend
# 183  Low-Income-High-Spend
# 185  Low-Income-High-Spend
# 187  Low-Income-High-Spend
# 189  Low-Income-High-Spend
# 191  Low-Income-High-Spend
# 193  Low-Income-High-Spend
# 195  Low-Income-High-Spend
# 197  Low-Income-High-Spend
# 199  Low-Income-High-Spend

# %%
df_Low_Income_High_Spend.to_csv('df_Low_Income_High_Spend.csv')
